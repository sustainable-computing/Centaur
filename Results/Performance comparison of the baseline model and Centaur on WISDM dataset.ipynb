# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

excel_file = pd.ExcelFile('End-to-end robust multimodal fusion_WISDM.xlsx')
sheet_names = excel_file.sheet_names

sheet_name = 'mode1'  
df_mode1 = excel_file.parse(sheet_name)

# For example, print the first few rows
print(df_mode1.head())
# Out:
#      ModelName  Mode  Corr        Acc       Std
# 0      Centaur     1  0.00  96.790000  0.487545
# 1        UniTS     1  0.00  93.120000  0.516430
# 2  SADeepSense     1  0.00  90.523333  0.168028
# 3      Centaur     1  0.05  87.531667  0.327414
# 4        UniTS     1  0.05  85.440000  0.433474

# %%
cmap = plt.get_cmap("tab10")
my_cmap=['khaki', 'seagreen', 'orange', 'cornflowerblue']

# %%
#fig, axs = plt.subplots(1, 1,1)


width =0.25

plt.rcParams["figure.figsize"] = "12, 9"
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = "28"

fig, ax = plt.subplots()
ax.grid(linestyle=':',zorder=0)

# plot 1
labels = ['0','0.05','0.1','0.2']

#SADeepSense = [66.17333333,63.47666667,61.32333333,43.47333333] # final
df_centaur = df_mode1[df_mode1["ModelName"] == "Centaur"]
df_units = df_mode1[df_mode1["ModelName"] == "UniTS"]
df_sad = df_mode1[df_mode1["ModelName"] == "SADeepSense"]



x = np.arange(len(labels))  # the label locations
ax.grid(linestyle=':',zorder=0)
rects1 = ax.bar(x - width*0.5, df_centaur["Acc"], width, yerr=df_centaur["Std"], label='Centaur', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[3], hatch="O")
rects2 = ax.bar(x + width*0.5 , df_units["Acc"], width, yerr= df_units["Std"], label='UniTS', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[2], hatch="/")
rects3 = ax.bar(x + width*1.5, df_sad["Acc"], width, yerr=df_sad["Std"], label='SADeepSense', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[1], hatch="X")

hatch="/"
hatch ="-"
ax.set_ylim(0,100)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)',fontsize=32)
ax.set_xlabel('Noise intensity (σ)')
ax.set_xlabel('Corruption Mode 1',labelpad = 10, fontsize=32)
# ax.set_title('Scores by group and gender')
ax.set_xticks([0,1,2,3])
ax.set_xticklabels(['$σ$ =0', '$σ$ =0.05', '$σ$= 0.1', '$σ$= 0.2'])
ax.set_xticks(x, labels)


handles,labels = ax.get_legend_handles_labels()
handles = [handles[0],handles[1], handles[2]]
labels = [labels[0],labels[1], labels[2]]
ax.legend(handles,labels,loc='lower left',fontsize=35,facecolor='white', framealpha=1)
ax.tick_params(axis='x', which='major', pad=15)


fig.savefig('WISDM_corruptionmode1.pdf',  format='eps', dpi=300)
plt.show()
plt.close(fig)
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
sheet_name = 'mode2' 
df_mode1 = excel_file.parse(sheet_name)

print(df_mode1.head())
# Out:
#      ModelName  Mode   Corr        Acc       Std
# 0      Centaur     2      0  96.790000  0.487545
# 1        UniTS     2      0  93.120000  0.516430
# 2  SADeepSense     2      0  90.523333  0.168028
# 3      Centaur     2  30,70  93.586000  0.516943
# 4        UniTS     2  30,70  90.650000  0.022361

# %%
#fig, axs = plt.subplots(1, 1,1)


width =0.25

plt.rcParams["figure.figsize"] = "12, 9"
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = "28"

fig, ax = plt.subplots()
ax.grid(linestyle=':',zorder=0)

# plot 1
labels = ['0','0.05','0.1','0.2']

#SADeepSense = [66.17333333,63.47666667,61.32333333,43.47333333] # final
df_centaur = df_mode1[df_mode1["ModelName"] == "Centaur"]
df_units = df_mode1[df_mode1["ModelName"] == "UniTS"]
df_sad = df_mode1[df_mode1["ModelName"] == "SADeepSense"]



x = np.arange(len(labels))  # the label locations
ax.grid(linestyle=':',zorder=0)
rects1 = ax.bar(x - width*0.5, df_centaur["Acc"], width, yerr=df_centaur["Std"], label='Centaur', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[3], hatch="O")
rects2 = ax.bar(x + width*0.5 , df_units["Acc"], width, yerr= df_units["Std"], label='UniTS', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[2], hatch="/")
rects3 = ax.bar(x + width*1.5, df_sad["Acc"], width, yerr=df_sad["Std"], label='SADeepSense', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[1], hatch="X")

hatch="/"
hatch ="-"
ax.set_ylim(0,100)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)',fontsize=32)
ax.set_xlabel('Noise intensity (σ)')
ax.set_xlabel('Corruption Mode 2',labelpad = 10, fontsize=32)
# ax.set_title('Scores by group and gender')
ax.set_xticks([0,1,2,3])
ax.set_xticklabels(['$s_{corr}$ =0 \n $s_{norm}$ =$\infty$', '$s_{corr}$ =30 \n $s_{norm}$ =70', '$s_{corr}$ =40 \n $s_{norm}$ =70', '$s_{corr}$ =50 \n $s_{norm}$ =70'],fontsize=29)
ax.set_xticks(x, labels)


handles,labels = ax.get_legend_handles_labels()
handles = [handles[0],handles[1], handles[2]]
labels = [labels[0],labels[1], labels[2]]
ax.legend(handles,labels,loc='lower left',fontsize=35,facecolor='white', framealpha=1)
ax.tick_params(axis='x', which='major', pad=15)


fig.savefig('WISDM_corruptionmode2.pdf',  format='eps', dpi=300)
plt.show()
plt.close(fig)
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
sheet_name = 'mode4'  
df_mode1 = excel_file.parse(sheet_name)

print(df_mode1.head())
# Out:
#      ModelName  Mode        Corr        Acc       Std
# 0      Centaur     4           0  96.790000  0.487545
# 1        UniTS     4           0  93.120000  0.516430
# 2  SADeepSense     4           0  90.523333  0.168028
# 3      Centaur     4  0.05,30,70  86.752000  0.454170
# 4        UniTS     4  0.05,30,70  84.354000  0.020736

# %%
#fig, axs = plt.subplots(1, 1,1)


width =0.25

plt.rcParams["figure.figsize"] = "12, 9"
plt.rcParams["font.family"] = "Arial"
plt.rcParams["font.size"] = "28"

fig, ax = plt.subplots()
ax.grid(linestyle=':',zorder=0)

# plot 1
labels = ['0','0.05','0.1','0.2']

#SADeepSense = [66.17333333,63.47666667,61.32333333,43.47333333] # final
df_centaur = df_mode1[df_mode1["ModelName"] == "Centaur"]
df_units = df_mode1[df_mode1["ModelName"] == "UniTS"]
df_sad = df_mode1[df_mode1["ModelName"] == "SADeepSense"]



x = np.arange(len(labels))  # the label locations
ax.grid(linestyle=':',zorder=0)
rects1 = ax.bar(x - width*0.5, df_centaur["Acc"], width, yerr=df_centaur["Std"], label='Centaur', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[3], hatch="O")
rects2 = ax.bar(x + width*0.5 , df_units["Acc"], width, yerr= df_units["Std"], label='UniTS', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[2], hatch="/")
rects3 = ax.bar(x + width*1.5, df_sad["Acc"], width, yerr=df_sad["Std"], label='SADeepSense', zorder=3, capsize=10, edgecolor='black',fill=True,color=my_cmap[1], hatch="X")

hatch="/"
hatch ="-"
ax.set_ylim(0,100)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy (%)',fontsize=32)
ax.set_xlabel('Noise intensity (σ)')
ax.set_xlabel('Corruption Mode 4',labelpad = 10, fontsize=32)
# ax.set_title('Scores by group and gender')
ax.set_xticks([0,1,2,3])
ax.set_xticklabels(['$σ$=0 \n $s_{corr}$ =0 \n $s_{norm}$ =$\infty$', '$σ$=0.05\n $s_{corr}$ =30 \n $s_{norm}$ =70', '$σ$=0.1 \n $s_{corr}$ =40 \n $s_{norm}$ =70', '$σ$=0.2 \n $s_{corr}$ =50 \n $s_{norm}$ =70'],fontsize=29)
ax.set_xticks(x, labels)


handles,labels = ax.get_legend_handles_labels()
handles = [handles[0],handles[1], handles[2]]
labels = [labels[0],labels[1], labels[2]]
ax.legend(handles,labels,loc='lower left',fontsize=35,facecolor='white', framealpha=1)
ax.tick_params(axis='x', which='major', pad=15)


fig.savefig('WISDM_corruptionmode4.pdf',  format='eps', dpi=300)
plt.show()
plt.close(fig)
